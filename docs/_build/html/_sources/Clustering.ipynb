# %% [markdown]
# # Clustering Similar Cells
#
# iasuhfuaysgduyagdiuaguasyfo
#
# [Click here to see Brad Tutorial](https://www.sc-best-practices.org/introduction/scrna_seq.html)
# ![image.jpg](https://www.sc-best-practices.org/_images/anndata.jpg)

# %%
so <- filter
